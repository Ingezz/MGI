# %%
import pandas
import subprocess
import glob
import os

# %% [markdown]
# ## New files processed:
# /data/archive/17-05-05-glass/ES_project/
#
# /data/archive/17-05-05-glass/ES_project/RNA_retina/C57BL6
# /data/archive/17-05-05-glass/ES_project/RNA_retina/DBA
#
#
# #### Not processed in the overview files. Have other files been generated??
# /data/archive/17-02-14-glass/project_ES/retina/C57BL6/
# /data/archive/17-02-14-glass/project_ES/retina/DBA/

# %%
## file://localhost/Volumes/Epiglass/data/archive/17-05-05-glass/ES_project/C57BL6_Endoret_RNA_Hprx_Tn5_ES_16_08_19_S100_L007_R1_001.fastq.gz
## Files located on:  
/data/archive/17-05-05-glass/ES_project/
/data/archive/17-02-14-glass/

# %%
print("tscc")
print("screen")
print("export PATH=/projects/glass-group/bioinformatics/bin:$PATH")

dir_C57 = '/data/archive/17-02-14-glass/project_ES/retina/C57BL6_retina/'
dir_DBA = '/data/archive/17-02-14-glass/project_ES/retina/DBA_Retina/'

#dir_C57 = '/data/archive/17-05-05-glass/ES_project/RNA_retina/C57BL6/'
#dir_DBA = '/data/archive/17-05-05-glass/ES_project/RNA_retina/DBA/'

#print("map_on_oasis.sh rna mm10 iholtman@ucsd.edu " + dir_C57 + " -l -e")
print("map_on_oasis.sh rna mm10 iholtman@ucsd.edu " + dir_C57 + " -l -e")


##Some files are DBA that need to be reprocessed with DBA reference instead of MM10! 
print("map_on_oasis.sh rna dba2j iholtman@ucsd.edu " + dir_DBA + " -l -e -s ")


#map_on_oasis.sh rna dba2j iholtman@ucsd.edu /data/archive/16-06-21-glass/Project_Eniko/DBA -m -s
# Out:
# tscc
# screen
# export PATH=/projects/glass-group/bioinformatics/bin:$PATH
# map_on_oasis.sh rna mm10 iholtman@ucsd.edu /data/archive/17-02-14-glass/project_ES/retina/C57BL6_retina/ -l -e
# map_on_oasis.sh rna dba2j iholtman@ucsd.edu /data/archive/17-02-14-glass/project_ES/retina/DBA_Retina/ -l -e -s

# %%
##Shift the DBA SAM files to match MM10 reference genome and make tagdirs ! 
##perl /home/vlink/mouse_strains/marge/shifting/shift_files_to_reference_textfiles.pl -files DBA_Endoret_RNA_Hprx_Tn5_ES_16_09_02, DBA_Endoret_RNA_Nx_Tn5_old_ES_16_10_12 -tag -ind dba2j
code = 'perl /home/vlink/mouse_strains/marge/shifting/shift_files_to_reference_textfiles.pl -dir /data/scratch/iholtman/ES_project_DBA/tag_directories/' + ' /data/scratch/iholtman/ES_project_DBA/tag_directories/'.join(dirs) + ' -ind dba2j '
print(code)

print(subprocess.check_output(code, shell=True, stderr=subprocess.STDOUT).decode()) ##
# Out:
# perl /home/vlink/mouse_strains/marge/shifting/shift_files_to_reference_textfiles.pl -dir /data/scratch/iholtman/ES_project_DBA/tag_directories/C57BL6_AMhigh_RNA_PND1_ES_17_02_16 /data/scratch/iholtman/ES_project_DBA/tag_directories/C57BL6_AMhigh_RNA_Tn5_PND0_ES_17_03_23 /data/scratch/iholtman/ES_project_DBA/tag_directories/C57BL6_AMlow_RNA_PND0_ES_17_03_23_1 /data/scratch/iholtman/ES_project_DBA/tag_directories/C57BL6_AMlow_RNA_PND0_ES_17_03_23_2 /data/scratch/iholtman/ES_project_DBA/tag_directories/C57BL6_AMlow_RNA_PND1_ES_17_02_16_1 /data/scratch/iholtman/ES_project_DBA/tag_directories/C57BL6_AMlow_RNA_PND1_ES_17_02_16_2 /data/scratch/iholtman/ES_project_DBA/tag_directories/C57BL6_Endoret_RNA_Hprx_Tn5_ES_16_08_19 /data/scratch/iholtman/ES_project_DBA/tag_directories/C57BL6_Endoret_RNA_Hprx_Tn5_PND15_ES_16_08_18 /data/scratch/iholtman/ES_project_DBA/tag_directories/C57BL6_Endoret_RNA_Hprx_Tn5_PND15_ES_16_08_18_2 /data/scratch/iholtman/ES_project_DBA/tag_directories/C57BL6_Endoret_RN
# ...

# %%
files = glob.glob('/data/scratch/iholtman/project_ES/tag_directories/*')
files2 = glob.glob('/data/scratch/iholtman/ES_project_DBA/tag_directories/*')

all_reps = files + files2 
print(files)
# Out:
# ['/data/scratch/iholtman/project_ES/tag_directories/C57Bl6_MGretina_RNA_Tn5_Hprx_ES_16_09_02', '/data/scratch/iholtman/project_ES/tag_directories/DBA_MGretina_RNA_Tn5_Nx_PND16_ES_16_09_23', '/data/scratch/iholtman/project_ES/tag_directories/C57Bl6_EndoRet_RNA_Tn5_Nx_PND15_ES_16_09_23', '/data/scratch/iholtman/project_ES/tag_directories/C57Bl6_IMo_RNA_Tn5_LPS_12h_ES_16_06_23', '/data/scratch/iholtman/project_ES/tag_directories/DBA_EndoRet_RNA_Tn5_Nx_PND16_ES_16_09_23', '/data/scratch/iholtman/project_ES/tag_directories/DBA_MGretina_RNA_Tn5_Nx_ES_16_09_02', '/data/scratch/iholtman/project_ES/tag_directories/DBA_MGretina_RNA_Tn5_Hprx_PND15_ES_16_09_23', '/data/scratch/iholtman/project_ES/tag_directories/C57Bl6_MGretina_RNA_Tn5_Nx_ES_16_09_02', '/data/scratch/iholtman/project_ES/tag_directories/C57Bl6_EndoRet_RNA_Tn5_Nx_ES_16_09_02', '/data/scratch/iholtman/project_ES/tag_directories/DBA_EndoRet_RNA_Tn5_Hprx_ES_16_09_02', '/data/scratch/iholtman/project_ES/tag_directories/C57Bl6_MGretina
# ...

# %%
output_file = '/gpfs/data01/glasslab/home/iholtman/Project_hyperoxia_Eniko/count_data/RNA-seq/retina/count_May_24th_'

homer_cmd_line = 'analyzeRepeats.pl rna mm10 -raw -normMatrix 1e7 -pc 3 -count exons -strand both -condenseGenes -d {} > {}'.format(' '.join(all_reps), output_file)

print(homer_cmd_line)

print(subprocess.check_output(code, shell=True, stderr=subprocess.STDOUT).decode()) ##

# %% [markdown]
# ## Overview file and processing!

# %%
##Read overview file 
Overview = pandas.read_csv("/gpfs/data01/glasslab/home/esajti/Project_hyperoxia_overview_files/Overview_RNA-seq_Dec_5th_2016.csv")
print(Overview)
# Out:
#                                          Fastq_path  \
# 0                                                 ?
# 1                                                 ?
# 2                                                 ?
# 3    /data/archive/16-06-21-glass/Project_Eniko/C57
# 4    /data/archive/16-06-21-glass/Project_Eniko/C57
# 5    /data/archive/16-06-21-glass/Project_Eniko/C57
# 6    /data/archive/16-06-21-glass/Project_Eniko/C57
# 7    /data/archive/16-06-21-glass/Project_Eniko/C57
# 8    /data/archive/16-06-21-glass/Project_Eniko/C57
# 9    /data/archive/16-06-21-glass/Project_Eniko/C57
# 10   /data/archive/16-06-21-glass/Project_Eniko/C57
# 11   /data/archive/16-06-21-glass/Project_Eniko/C57
# 12   /data/archive/16-06-21-glass/Project_Eniko/C57
# 13   /data/archive/16-06-21-glass/Project_Eniko/C57
# 14                                                ?
# 15                                                ?
# 16                                                ?
# ...

# %%
MG_overview = Overview[Overview["Cell_type"] == "MG"]
print(MG_overview)

OUTPUT_PATH = "/gpfs/data01/glasslab/home/iholtman/Project_hyperoxia_Eniko/"
MG_overview.to_csv(os.path.join(OUTPUT_PATH, 'MG_samples_dec_5th.csv'))
# Out:
#                                          Fastq_path  \
# 0                                                 ?
# 1                                                 ?
# 2                                                 ?
# 59   /data/archive/16-06-21-glass/Project_Eniko/C57
# 60                                                ?
# 61    /data/archive/16-06-08-glass/Project_Johannes
# 62    /data/archive/16-06-08-glass/Project_Johannes
# 63    /data/archive/16-06-08-glass/Project_Johannes
# 64                                                ?
# 65                                                ?
# 66   /data/archive/16-06-21-glass/Project_Eniko/C57
# 67                                                ?
# 68                                                ?
# 99                                                ?
# 100                                               ?
# 101                                               ?
#
#                                             Fastq_file  \
# ...

# %%
##Make a subselection of files that are sequenced but not processed and generate the code for alignment in TSCC

seq_overview = Overview[Overview["STATUS (sorted, sequenced, tagdir,  QC, moved, processed)"] == "moved"]
#print(seq_overview)

DIRS = list(set(seq_overview["Fastq_path"]))

print("tscc")
print("screen")
print("export PATH='/projects/glass-group/bioinformatics/bin:$PATH'")

for dir in DIRS:
    print("map_on_oasis.sh rna mm10 iholtman@ucsd.edu " + dir + " -l -e")

#map_on_oasis.sh rna dba2j iholtman@ucsd.edu /data/archive/16-06-21-glass/Project_Eniko/DBA -m -s
# Out:
# tscc
# screen
# export PATH='/projects/glass-group/bioinformatics/bin:$PATH'
# map_on_oasis.sh rna mm10 iholtman@ucsd.edu ? -l -e
# map_on_oasis.sh rna mm10 iholtman@ucsd.edu /data/archive/16-06-21-glass/Project_Eniko/C57 -l -e
# map_on_oasis.sh rna mm10 iholtman@ucsd.edu /data/archive/16-03-08-glass/Project_Jason/ -l -e
# map_on_oasis.sh rna mm10 iholtman@ucsd.edu /data/archive/16-03-08-glass/Project_Eniko -l -e
# map_on_oasis.sh rna mm10 iholtman@ucsd.edu /data/archive/16-06-08-glass/Project_Johannes -l -e
# map_on_oasis.sh rna mm10 iholtman@ucsd.edu /data/archive/16-11-06-glass/Project_Eniko/RNA -l -e

# %%
fastq_dir1 = glob.glob("/data/archive/16-03-08-glass/Project_Jason/*.fastq.gz")
fastq_dir2 = glob.glob("/data/archive/16-11-06-glass/Project_Eniko/RNA/*.fastq.gz")
fastq_dir3 = glob.glob("/data/archive/16-03-08-glass/Project_Eniko/*.fastq.gz")

FASTQ = fastq_dir1 + fastq_dir2 + fastq_dir3 
print(FASTQ)
# Out:
# ['/data/archive/16-03-08-glass/Project_Jason/NCoRWT_Kupffer_RNA_polyA_CCl4_24h_LN112b_JSS_16_01_21_S95_L005_R1_001.fastq.gz', '/data/archive/16-03-08-glass/Project_Jason/NCoRWT_LSEC_RNA_polyA_CCl4_24h_LN112b_JSS_16_01_21_S97_L006_R1_001.fastq.gz', '/data/archive/16-03-08-glass/Project_Jason/NCoRKO_Kupffer_RNA_polyA_CCl4_24h_LN106a_JSS_16_01_21_S93_L005_R1_001.fastq.gz', '/data/archive/16-03-08-glass/Project_Jason/NCoRWT_LungIntMac_RNA_polyA_Pool_JSS_16_01_27_S84_L005_R1_001.fastq.gz', '/data/archive/16-03-08-glass/Project_Jason/NCoRKO_AlveolarMac_RNA_polyA_Pool_JSS_16_01_27_S87_L005_R1_001.fastq.gz', '/data/archive/16-03-08-glass/Project_Jason/NCoRKO_LundDC_RNA_polyA_Pool_JSS_16_01_27_S89_L005_R1_001.fastq.gz', '/data/archive/16-03-08-glass/Project_Jason/NCoRWT_LundDC_RNA_polyA_Pool_JSS_16_01_27_S85_L005_R1_001.fastq.gz', '/data/archive/16-03-08-glass/Project_Jason/NCoRWT_AlveolarMac_RNA_polyA_TissueCulture_48h_Pool_JSS_16_01_27_S91_L005_R1_001.fastq.gz', '/data/archive/16-03-08-glas
# ...

# %%
##make a selection of the overview-file for QC and perform QC!  
## Tagdirs 
seq_overview = Overview[Overview["STATUS (sorted, sequenced, tagdir,  QC, moved, processed)"] == "tagdir"]
tag_dir= list(set(seq_overview["Tagdir_path"]+ seq_overview["Tagdir"]))


####### 
tag_dir1 = list(glob.glob("/data/scratch/iholtman/RNA/tag_directories/*"))
tag_dir2 = glob.glob("/data/scratch/iholtman/Project_Eniko/tag_directories/*")
tag_dir3 = glob.glob("/data/scratch/iholtman/Project_Jason/tag_directories/*")

TAGS = tag_dir1 + tag_dir2 + tag_dir3
  
    
#", ".join(str(e) for e in s)

terminal_process = "summarize_logs.py rna /gpfs/data01/glasslab/home/iholtman/Project_hypoxia_Eniko_QC_Dec_1st " + str(TAGS)


print(terminal_process)
#for dir in TAGS:
#    print(dir)



#print(subprocess.check_output(terminal_process, shell=True, stderr=subprocess.STDOUT).decode()) ##
#print(terminal_process)

#print("\n" + str(tag_dir1))
# Out:
# summarize_logs.py rna /gpfs/data01/glasslab/home/iholtman/Project_hypoxia_Eniko_QC_Dec_1st ['/data/scratch/iholtman/RNA/tag_directories/CN_Kidney_IMo_RNA_Tn5LowInput_E10_ES', '/data/scratch/iholtman/RNA/tag_directories/WT_Kidney_Neutro_RNA_Tn5LowInput_E5_ES', '/data/scratch/iholtman/RNA/tag_directories/CN_Kidney_Mac_RNA_Tn5LowInput_E8_ES', '/data/scratch/iholtman/RNA/tag_directories/CN_Kidney_Neutro_RNA_Tn5LowInput_E6_ES', '/data/scratch/iholtman/RNA/tag_directories/C57BL6_Lung_AMCD64H_RNA_Tn5LowInput_E1_ES', '/data/scratch/iholtman/RNA/tag_directories/C57BL8_Lung_PMo_RNA_Tn5LowInput_E3_ES', '/data/scratch/iholtman/RNA/tag_directories/C57BL7_Lung_IM_RNA_Tn5LowInput_E2_ES', '/data/scratch/iholtman/RNA/tag_directories/WT_Kidney_IMo_RNA_Tn5LowInput_E9_ES', '/data/scratch/iholtman/RNA/tag_directories/WT_Kidney_Mac_RNA_Tn5LowInput_E7_ES', '/data/scratch/iholtman/RNA/tag_directories/C57BL9_Lung_AMCD64L_RNA_Tn5LowInput_E4_ES', '/data/scratch/iholtman/Project_Eniko/tag_directories/PPARgWT_Mo
# ...

# %%
##QC brain samples from jupyter 

seq_overview = Overview[Overview["STATUS (sorted, sequenced, tagdir,  QC, moved, processed)"] == "tagdir"]
tag_dir= list(set(seq_overview["Tagdir_path"]+ seq_overview["Tagdir"]))

OUTPUT_PATH = "/gpfs/data01/glasslab/home/iholtman/Project_hyperoxia_Eniko/QC/Dec_6th"


terminal_process = 'summarize_logs.py rna ' + OUTPUT_PATH + ' {}  {}'.format(' '.join(tag_dir), '')

#print(terminal_process)
print(subprocess.check_output(terminal_process, shell=True, stderr=subprocess.STDOUT).decode())
# Out:
# /gpfs/data01/glasslab/home/iholtman/anaconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
fastq_dir1 = glob.glob("/data/archive/16-03-08-glass/Project_Jason/*.fastq.gz")
fastq_dir2 = glob.glob("/data/archive/16-11-06-glass/Project_Eniko/RNA/*.fastq.gz")
fastq_dir3 = glob.glob("/data/archive/16-03-08-glass/Project_Eniko/*.fastq.gz")

FASTQ = fastq_dir1 + fastq_dir2 + fastq_dir3 
print(FASTQ)



####### 
tag_dir1 = list(glob.glob("/data/scratch/iholtman/RNA/tag_directories/*"))
tag_dir2 = glob.glob("/data/scratch/iholtman/Project_Eniko/tag_directories/*")
tag_dir3 = glob.glob("/data/scratch/iholtman/Project_Jason/tag_directories/*")

TAGS = tag_dir1 + tag_dir2 + tag_dir3


print("\n" + str(TAGS))

print("TAGS =" + str(len(TAGS)) +  " FASTQ = " + str(len(FASTQ)))
# Out:
# ['/data/archive/16-03-08-glass/Project_Jason/NCoRWT_Kupffer_RNA_polyA_CCl4_24h_LN112b_JSS_16_01_21_S95_L005_R1_001.fastq.gz', '/data/archive/16-03-08-glass/Project_Jason/NCoRWT_LSEC_RNA_polyA_CCl4_24h_LN112b_JSS_16_01_21_S97_L006_R1_001.fastq.gz', '/data/archive/16-03-08-glass/Project_Jason/NCoRKO_Kupffer_RNA_polyA_CCl4_24h_LN106a_JSS_16_01_21_S93_L005_R1_001.fastq.gz', '/data/archive/16-03-08-glass/Project_Jason/NCoRWT_LungIntMac_RNA_polyA_Pool_JSS_16_01_27_S84_L005_R1_001.fastq.gz', '/data/archive/16-03-08-glass/Project_Jason/NCoRKO_AlveolarMac_RNA_polyA_Pool_JSS_16_01_27_S87_L005_R1_001.fastq.gz', '/data/archive/16-03-08-glass/Project_Jason/NCoRKO_LundDC_RNA_polyA_Pool_JSS_16_01_27_S89_L005_R1_001.fastq.gz', '/data/archive/16-03-08-glass/Project_Jason/NCoRWT_LundDC_RNA_polyA_Pool_JSS_16_01_27_S85_L005_R1_001.fastq.gz', '/data/archive/16-03-08-glass/Project_Jason/NCoRWT_AlveolarMac_RNA_polyA_TissueCulture_48h_Pool_JSS_16_01_27_S91_L005_R1_001.fastq.gz', '/data/archive/16-03-08-glas
# ...

# %%
###Directories with new sequencing files 
import glob
import os
import re

#line = re.sub('[!@#$]', '', line)

####### 
tag_dir1 = list(glob.glob("/data/scratch/iholtman/RNA/tag_directories/*"))
tag_dir1 = [s.replace("/data/scratch/iholtman/RNA/tag_directories/", '') for s in tag_dir1]

tag_dir2 = glob.glob("/data/scratch/iholtman/Project_Eniko/tag_directories/*")
tag_dir2 = [s.replace("/data/scratch/iholtman/Project_Eniko/tag_directories/", '') for s in tag_dir2]

tag_dir3 = glob.glob("/data/scratch/iholtman/Project_Jason/tag_directories/*")
tag_dir3 = [s.replace("/data/scratch/iholtman/Project_Jason/tag_directories/", '') for s in tag_dir3]

print(tag_dir1, tag_dir2, tag_dir3)
# Out:
# ['CN_Kidney_IMo_RNA_Tn5LowInput_E10_ES', 'WT_Kidney_Neutro_RNA_Tn5LowInput_E5_ES', 'CN_Kidney_Mac_RNA_Tn5LowInput_E8_ES', 'CN_Kidney_Neutro_RNA_Tn5LowInput_E6_ES', 'C57BL6_Lung_AMCD64H_RNA_Tn5LowInput_E1_ES', 'C57BL8_Lung_PMo_RNA_Tn5LowInput_E3_ES', 'C57BL7_Lung_IM_RNA_Tn5LowInput_E2_ES', 'WT_Kidney_IMo_RNA_Tn5LowInput_E9_ES', 'WT_Kidney_Mac_RNA_Tn5LowInput_E7_ES', 'C57BL9_Lung_AMCD64L_RNA_Tn5LowInput_E4_ES'] ['PPARgWT_Mono_RNA_P4b_12_lowinput_ES', 'PPARgKO_Mono_RNA_P4a_4_lowinput_ES', 'PPARgKO_Mono_RNA_P4a2_5x_lowinput_ES', 'PPARgWT_Mono_RNA_P4b2_lowinput_ES', 'PPARgWT_AM_RNA_lowinput_ES', 'PPARgKO_AM_RNA_lowinput_ES', 'PPARgKO_Mono_RNA_P4a2_lowinput_ES', 'PPARgKO_DC_RNA_lowinput_ES', 'PPARgKO_Mono_RNA_lowinput_ES', 'PPARgWT_IM_RNA_lowinput_ES', 'PPARgWT_Mono_RNA_P4b_9_lowinput_ES', 'PPARgWT_Mono_RNA_lowinput_ES', 'PPARgKO_IM_RNA_lowinput_ES', 'PPARgKO_Mono_RNA_P4a2_5_lowinput_ES', 'PPARgWT_DC_RNA_lowinput_ES', 'PPARgWT_Mono_RNA_P4b2_5x_lowinput_ES'] ['NCoRKO_AlveolarMac_RNA_polyA_T
# ...

# %%
##Make an overview file with subselection of which the QC is performed for copying to general datastructure 
seq_overview = Overview[Overview["STATUS (sorted, sequenced, tagdir,  QC, moved, processed)"] == "QC"]


#print(seq_overview)
#tag_dir1 = list(glob.glob("/data/scratch/iholtman/RNA/tag_directories/*"))
#tag_dir1 = [s.replace("/data/scratch/iholtman/RNA/tag_directories/", '') for s in tag_dir1]

#tag_dir2 = glob.glob("/data/scratch/iholtman/Project_Eniko/tag_directories/*")
#tag_dir2 = [s.replace("/data/scratch/iholtman/Project_Eniko/tag_directories/", '') for s in tag_dir2]

#tag_dir3 = glob.glob("/data/scratch/iholtman/Project_Jason/tag_directories/*")
#tag_dir3 = [s.replace("/data/scratch/iholtman/Project_Jason/tag_directories/", '') for s in tag_dir3]


tag_dir1 = glob.glob("/data/scratch/iholtman/RNA/tag_directories/*")
tag_dir2 = glob.glob("/data/scratch/iholtman/Project_Eniko/tag_directories/*")
tag_dir3 = glob.glob("/data/scratch/iholtman/Project_Jason/tag_directories/*")

tag_dir = tag_dir1 + tag_dir2 + tag_dir3

tag_dir = pandas.DataFrame([], index=tag_dir)

#DIRS = list(set(seq_overview["fastq_path"]))
tag_dir['mono'] = [i.lower().find('mono') > -1 for i in tag_dir.index]
tag_dir['alveolarmac'] = [i.lower().find('alveolarmac') > -1 for i in tag_dir.index]
tag_dir['neutro'] = [i.lower().find('neutro') > -1 for i in tag_dir.index]
tag_dir['dc'] = [i.lower().find('dc') > -1 for i in tag_dir.index]
tag_dir['am'] = [i.lower().find('am') > -1 for i in tag_dir.index]
tag_dir['pmo'] = [i.lower().find('pmo') > -1 for i in tag_dir.index]
tag_dir['neutro'] = [i.lower().find('neutro') > -1 for i in tag_dir.index]
tag_dir['kupffer'] = [i.lower().find('kupff') > -1 for i in tag_dir.index]
tag_dir['im'] = [i.lower().find('im') > -1 for i in tag_dir.index]
tag_dir['kidney_mac'] = [i.lower().find('kidney_mac') > -1 for i in tag_dir.index]
tag_dir['lung_im'] = [i.lower().find('LungIntMac') > -1 for i in tag_dir.index]
tag_dir['kidney_mac'] = [i.lower().find('kidney_mac') > -1 for i in tag_dir.index]
tag_dir['Kidney_imo'] = [i.lower().find('Kidney_imo') > -1 for i in tag_dir.index]
tag_dir['lsec'] = [i.lower().find('lsec') > -1 for i in tag_dir.index]
tag_dir['lungintmac'] = [i.lower().find('lungintmac') > -1 for i in tag_dir.index]

print(tag_dir)




###
rows    = (tag_dir != 0).sum(1)
print(rows)
# Out:
#                                                      mono alveolarmac neutro  \
# /data/scratch/iholtman/RNA/tag_directories/CN_K...  False       False  False
# /data/scratch/iholtman/RNA/tag_directories/WT_K...  False       False   True
# /data/scratch/iholtman/RNA/tag_directories/CN_K...  False       False  False
# /data/scratch/iholtman/RNA/tag_directories/CN_K...  False       False   True
# /data/scratch/iholtman/RNA/tag_directories/C57B...  False       False  False
# /data/scratch/iholtman/RNA/tag_directories/C57B...  False       False  False
# /data/scratch/iholtman/RNA/tag_directories/C57B...  False       False  False
# /data/scratch/iholtman/RNA/tag_directories/WT_K...  False       False  False
# /data/scratch/iholtman/RNA/tag_directories/WT_K...  False       False  False
# /data/scratch/iholtman/RNA/tag_directories/C57B...  False       False  False
# /data/scratch/iholtman/Project_Eniko/tag_direct...   True       False  False
# ...

# %%
#for index,type in tag_dir:
#    if type["mono"] == True:
#print(cell)

############## 
##Destinations 

for index, row in tag_dir.iterrows():
    if row["mono"] == True:
        print("cp -R " + index + " /data/mm10/Monocyte/RNA/")
    
    if row["alveolarmac"] == True:
        print("cp -R " + index + " /data/mm10/Lung-Macrophage/RNA/")

    if row["neutro"] == True:
        print("cp -R " + index + " /data/mm10/Neutrophils/RNA/")

    if row["dc"] == True:
        print("cp -R " + index + " /data/mm10/Lung-DC/RNA/")
        
    if row["am"] == True:
        print("cp -R " + index + " /data/mm10/Lung-Macrophage/RNA/")

    if row["pmo"] == True:
        print("cp -R " + index + " /data/mm10/Monocyte/RNA/")

    if row["im"] == True:
        print("cp -R " + index + " /data/mm10/Lung-Macrophage/RNA/")
        
    if row["kidney_mac"] == True:
        print("cp -R " + index + " /data/mm10/kidney-macrophage/RNA/")

    if row["Kidney_imo"] == True:
        print("cp -R " + index + " /data/mm10/kidney-monocytes/RNA/")
        
    if row["lungintmac"] == True:
        print("cp -R " + index + " /data/mm10/Lung-Macrophage/RNA/")
    
#tag_dir_IM = tag_dir[tag_dir["im"] == True]
#print(tag_dir_IM)
# Out:
# cp -R /data/scratch/iholtman/RNA/tag_directories/CN_Kidney_IMo_RNA_Tn5LowInput_E10_ES /data/mm10/Lung-Macrophage/RNA/
# cp -R /data/scratch/iholtman/RNA/tag_directories/WT_Kidney_Neutro_RNA_Tn5LowInput_E5_ES /data/mm10/Neutrophils/RNA/
# cp -R /data/scratch/iholtman/RNA/tag_directories/CN_Kidney_Mac_RNA_Tn5LowInput_E8_ES /data/mm10/kidney-macrophage/RNA/
# cp -R /data/scratch/iholtman/RNA/tag_directories/CN_Kidney_Neutro_RNA_Tn5LowInput_E6_ES /data/mm10/Neutrophils/RNA/
# cp -R /data/scratch/iholtman/RNA/tag_directories/C57BL6_Lung_AMCD64H_RNA_Tn5LowInput_E1_ES /data/mm10/Lung-Macrophage/RNA/
# cp -R /data/scratch/iholtman/RNA/tag_directories/C57BL8_Lung_PMo_RNA_Tn5LowInput_E3_ES /data/mm10/Monocyte/RNA/
# cp -R /data/scratch/iholtman/RNA/tag_directories/C57BL7_Lung_IM_RNA_Tn5LowInput_E2_ES /data/mm10/Lung-Macrophage/RNA/
# cp -R /data/scratch/iholtman/RNA/tag_directories/WT_Kidney_IMo_RNA_Tn5LowInput_E9_ES /data/mm10/Lung-Macrophage/RNA/
# ...

# %%
#print(seq_overview) ## For EXCEL OVERVIEW FILE 

tag_dir1 = list(glob.glob("/data/scratch/iholtman/RNA/tag_directories/*"))
tag_dir1 = [s.replace("/data/scratch/iholtman/RNA/tag_directories/", '') for s in tag_dir1]

tag_dir2 = glob.glob("/data/scratch/iholtman/Project_Eniko/tag_directories/*")
tag_dir2 = [s.replace("/data/scratch/iholtman/Project_Eniko/tag_directories/", '') for s in tag_dir2]

tag_dir3 = glob.glob("/data/scratch/iholtman/Project_Jason/tag_directories/*")
tag_dir3 = [s.replace("/data/scratch/iholtman/Project_Jason/tag_directories/", '') for s in tag_dir3]


tag_dir = tag_dir1 + tag_dir2 + tag_dir3

tag_dir = pandas.DataFrame([], index=tag_dir)

#DIRS = list(set(seq_overview["fastq_path"]))
tag_dir['mono'] = [i.lower().find('mono') > -1 for i in tag_dir.index]
tag_dir['alveolarmac'] = [i.lower().find('alveolarmac') > -1 for i in tag_dir.index]
tag_dir['neutro'] = [i.lower().find('neutro') > -1 for i in tag_dir.index]
tag_dir['dc'] = [i.lower().find('dc') > -1 for i in tag_dir.index]
tag_dir['am'] = [i.lower().find('am') > -1 for i in tag_dir.index]
tag_dir['pmo'] = [i.lower().find('pmo') > -1 for i in tag_dir.index]
tag_dir['neutro'] = [i.lower().find('neutro') > -1 for i in tag_dir.index]
tag_dir['kupffer'] = [i.lower().find('kupff') > -1 for i in tag_dir.index]
tag_dir['im'] = [i.lower().find('im') > -1 for i in tag_dir.index]
tag_dir['kidney_mac'] = [i.lower().find('kidney_mac') > -1 for i in tag_dir.index]
tag_dir['lung_im'] = [i.lower().find('LungIntMac') > -1 for i in tag_dir.index]
tag_dir['kidney_mac'] = [i.lower().find('kidney_mac') > -1 for i in tag_dir.index]
tag_dir['Kidney_imo'] = [i.lower().find('Kidney_imo') > -1 for i in tag_dir.index]
tag_dir['lsec'] = [i.lower().find('lsec') > -1 for i in tag_dir.index]
tag_dir['lungintmac'] = [i.lower().find('lungintmac') > -1 for i in tag_dir.index]



for index, row in tag_dir.iterrows():
    if row["mono"] == True:
        print(index + " /data/mm10/Monocyte/RNA/")
    
    if row["alveolarmac"] == True:
        print(index + " /data/mm10/Lung-Macrophage/RNA/")

    if row["neutro"] == True:
        print( index + " /data/mm10/Neutrophils/RNA/")

    if row["dc"] == True:
        print(index + " /data/mm10/Lung-DC/RNA/")
        
    if row["am"] == True:
        print( index + " /data/mm10/Lung-Macrophage/RNA/")

    if row["pmo"] == True:
        print(index + " /data/mm10/Monocyte/RNA/")

    if row["im"] == True:
        print(index + " /data/mm10/Lung-Macrophage/RNA/")
        
    if row["kidney_mac"] == True:
        print(index + " /data/mm10/kidney-macrophage/RNA/")

    if row["Kidney_imo"] == True:
        print(index + " /data/mm10/kidney-monocytes/RNA/")
        
    if row["lungintmac"] == True:
        print(index + "\t" + "/data/mm10/Lung-Macrophage/RNA/")
# Out:
# CN_Kidney_IMo_RNA_Tn5LowInput_E10_ES /data/mm10/Lung-Macrophage/RNA/
# WT_Kidney_Neutro_RNA_Tn5LowInput_E5_ES /data/mm10/Neutrophils/RNA/
# CN_Kidney_Mac_RNA_Tn5LowInput_E8_ES /data/mm10/kidney-macrophage/RNA/
# CN_Kidney_Neutro_RNA_Tn5LowInput_E6_ES /data/mm10/Neutrophils/RNA/
# C57BL6_Lung_AMCD64H_RNA_Tn5LowInput_E1_ES /data/mm10/Lung-Macrophage/RNA/
# C57BL8_Lung_PMo_RNA_Tn5LowInput_E3_ES /data/mm10/Monocyte/RNA/
# C57BL7_Lung_IM_RNA_Tn5LowInput_E2_ES /data/mm10/Lung-Macrophage/RNA/
# WT_Kidney_IMo_RNA_Tn5LowInput_E9_ES /data/mm10/Lung-Macrophage/RNA/
# WT_Kidney_Mac_RNA_Tn5LowInput_E7_ES /data/mm10/kidney-macrophage/RNA/
# C57BL9_Lung_AMCD64L_RNA_Tn5LowInput_E4_ES /data/mm10/Lung-Macrophage/RNA/
# PPARgWT_Mono_RNA_P4b_12_lowinput_ES /data/mm10/Monocyte/RNA/
# PPARgKO_Mono_RNA_P4a_4_lowinput_ES /data/mm10/Monocyte/RNA/
# PPARgKO_Mono_RNA_P4a2_5x_lowinput_ES /data/mm10/Monocyte/RNA/
# PPARgWT_Mono_RNA_P4b2_lowinput_ES /data/mm10/Monocyte/RNA/
# ...

# %%
##Read overview file 
Overview = pandas.read_csv("/gpfs/data01/glasslab/home/esajti/Project_hyperoxia_overview_files/Overview_RNA-seq_Dec_5th_2016.csv")

##Make a subselection of files that are sequenced but not processed and generate the code for alignment in TSCC
OUTPUT_PATH = "/gpfs/data01/glasslab/home/iholtman/Project_hyperoxia_Eniko/count_data/RNA-seq/overview/"

seq_overview = Overview[Overview["STATUS (sorted, sequenced, tagdir,  QC, moved, processed)"] == "moved"]

all_reps = list(seq_overview["Tagdir_path"] + seq_overview["Tagdir"])
#print(tagdir)
    
output_file = os.path.join(OUTPUT_PATH, 'mouse_rna_rpkm.tsv')
homer_cmd_line = 'analyzeRepeats.pl rna mm10 -rpkm -normMatrix 1e7 -pc 3 -count exons -strand both -condenseGenes -d {} > {}'.format(' '.join(all_reps), output_file)
print(homer_cmd_line)

#print(all_reps)
#print(subprocess.check_output(homer_cmd_line, shell=True, stderr=subprocess.STDOUT).decode()) ##
# Out:
# analyzeRepeats.pl rna mm10 -rpkm -normMatrix 1e7 -pc 3 -count exons -strand both -condenseGenes -d /data/mm10/Microglia/RNA/C57_Microglia_RNA_PolyA_PND14_Hyperoxia_1_DGO_16_04_04 /data/mm10/Microglia/RNA/C57_Microglia_RNA_PolyA_PND14_Normoxia_1_DGO_16_04_04 /data/mm10/Microglia/RNA/C57_Microglia_RNA_PolyA_PND49_Hyperoxia_1_DGO_16_04_04 /data/mm10/Lung-Macrophage/RNA/C57Bl6_AM_RNA_Hprx_ES_16_01_27 /data/mm10/Lung-Macrophage/RNA/C57Bl6_AM_RNA_Nx_ES_16_01_27 /data/mm10/Lung-Macrophage/RNA/C57Bl6_AM_RNA_PND10_ES_16_05_06 /data/mm10/Lung-Macrophage/RNA/C57Bl6_AMBAL_RNA_ES_16_03_24 /data/mm10/Lung-DC/RNA/C57Bl6_DC_RNA_48h_Nx_PND16_ES_16_02_10 /data/mm10/Lung-DC/RNA/C57Bl6_DC_RNA_Hprx_ES_16_01_27 /data/mm10/Lung-DC/RNA/C57Bl6_DC_RNA_Nx_ES_16_01_27 /data/mm10/Lung-DC/RNA/C57Bl6_DC_RNA_PND10_ES_16_05_06 /data/mm10/Lung-Macrophage/RNA/C57Bl6_IM_RNA_Hprx_ES_16_01_27 /data/mm10/Lung-Macrophage/RNA/C57Bl6_IM_RNA_Nx_ES_16_01_27 /data/mm10/Lung-Macrophage/RNA/C57Bl6_IM_RNA_PND10_ES_16_05_06 /data/m
# ...

# %%
import os 
import subprocess 

all_reps = ["/data/mm10/Microglia/RNA/C57Bl6_Microglia_RNA_PND14_Hprx_15_12_23_DGO_ES_16_04_04", \
"/data/mm10/Microglia/RNA/C57Bl6_Microglia_RNA_PND14_Nx_15_12_23_DGO_ES_16_04_04", \
"/data/mm10/Microglia/RNA/C57Bl6_Microglia_RNA_Hprx_16_01_27_DGO_ES_16_04_04", \
"/data/mm10/Microglia/RNA/C57Bl6_Microglia_RNA_Nx_16_01_27_DGO_ES_16_04_04_same_as_16_03_08", \
"/data/mm10/Microglia/RNA/C57BL6_Microglia_RNA_HyperoxiaFemale_JoS_16_02_10_CTTGTA", \
"/data/mm10/Microglia/RNA/C57BL6_Microglia_RNA_HyperoxiaMale_JoS_16_02_10_CAGATC", \
"/data/mm10/Microglia/RNA/C57BL6_Microglia_RNA_NormOxiaMale_JoS_16_02_10_TTAGGC", \
"/data/mm10/Microglia/RNA/C57Bl6_Microglia_RNA_Female_Hprx_ES_16_04_07", \
"/data/mm10/Microglia/RNA/C57Bl6_Microglia_RNA_Nx_ES_16_04_07"]


OUTPUT_PATH = "/gpfs/data01/glasslab/home/iholtman/Project_hyperoxia_Eniko/count_data/RNA-seq/microglia/"

    
output_file = os.path.join(OUTPUT_PATH, '20-12-2016-mouse_microglia_rna_raw.tsv')
homer_cmd_line = 'analyzeRepeats.pl rna mm10 -raw -normMatrix 1e7 -pc 3 -count exons -strand both -condenseGenes -d {} > {}'.format(' '.join(all_reps), output_file)
#print(homer_cmd_line)
print(subprocess.check_output(homer_cmd_line, shell=True, stderr=subprocess.STDOUT).decode())
# Out:
# 	Tag Directories:
# 		/data/mm10/Microglia/RNA/C57Bl6_Microglia_RNA_PND14_Hprx_15_12_23_DGO_ES_16_04_04
# 		/data/mm10/Microglia/RNA/C57Bl6_Microglia_RNA_PND14_Nx_15_12_23_DGO_ES_16_04_04
# 		/data/mm10/Microglia/RNA/C57Bl6_Microglia_RNA_Hprx_16_01_27_DGO_ES_16_04_04
# 		/data/mm10/Microglia/RNA/C57Bl6_Microglia_RNA_Nx_16_01_27_DGO_ES_16_04_04_same_as_16_03_08
# 		/data/mm10/Microglia/RNA/C57BL6_Microglia_RNA_HyperoxiaFemale_JoS_16_02_10_CTTGTA
# 		/data/mm10/Microglia/RNA/C57BL6_Microglia_RNA_HyperoxiaMale_JoS_16_02_10_CAGATC
# 		/data/mm10/Microglia/RNA/C57BL6_Microglia_RNA_NormOxiaMale_JoS_16_02_10_TTAGGC
# 		/data/mm10/Microglia/RNA/C57Bl6_Microglia_RNA_Female_Hprx_ES_16_04_07
# 		/data/mm10/Microglia/RNA/C57Bl6_Microglia_RNA_Nx_ES_16_04_07
# 	Input file format: homerRmsk
# 	Filtering based on repeat parameters: kept 35756 of 35756
# 	Calculating read coverage for /data/mm10/Microglia/RNA/C57Bl6_Microglia_RNA_PND14_Hprx_15_12_23_DGO_ES_16_04_04
# ...

# %%
########### COUNTS with HOMER 
output_file = os.path.join(OUTPUT_PATH, 'mouse_rna_read_counts.tsv')
homer_cmd_line = 'analyzeRepeats.pl rna mm10 -raw -pc 3 -count exons -strand both -condenseGenes -d {} > {}'.format(' '.join(all_reps), output_file)
#print(homer_cmd_line)
#print()
print(subprocess.check_output(homer_cmd_line, shell=True, stderr=subprocess.STDOUT).decode())
# Out:
# 	Tag Directories:
# 		/data/mm10/Microglia/RNA/C57_Microglia_RNA_PolyA_PND14_Hyperoxia_1_DGO_16_04_04
# 		/data/mm10/Microglia/RNA/C57_Microglia_RNA_PolyA_PND14_Normoxia_1_DGO_16_04_04
# 		/data/mm10/Microglia/RNA/C57_Microglia_RNA_PolyA_PND49_Hyperoxia_1_DGO_16_04_04
# 		/data/mm10/Lung-Macrophage/RNA/C57Bl6_AM_RNA_Hprx_ES_16_01_27
# 		/data/mm10/Lung-Macrophage/RNA/C57Bl6_AM_RNA_Nx_ES_16_01_27
# 		/data/mm10/Lung-Macrophage/RNA/C57Bl6_AM_RNA_PND10_ES_16_05_06
# 		/data/mm10/Lung-Macrophage/RNA/C57Bl6_AMBAL_RNA_ES_16_03_24
# 		/data/mm10/Lung-DC/RNA/C57Bl6_DC_RNA_48h_Nx_PND16_ES_16_02_10
# 		/data/mm10/Lung-DC/RNA/C57Bl6_DC_RNA_Hprx_ES_16_01_27
# 		/data/mm10/Lung-DC/RNA/C57Bl6_DC_RNA_Nx_ES_16_01_27
# 		/data/mm10/Lung-DC/RNA/C57Bl6_DC_RNA_PND10_ES_16_05_06
# 		/data/mm10/Lung-Macrophage/RNA/C57Bl6_IM_RNA_Hprx_ES_16_01_27
# 		/data/mm10/Lung-Macrophage/RNA/C57Bl6_IM_RNA_Nx_ES_16_01_27
# 		/data/mm10/Lung-Macrophage/RNA/C57Bl6_IM_RNA_PND10_ES_16_05_06
# ...

# %%
pandas_read
